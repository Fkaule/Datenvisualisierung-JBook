# %% [markdown]
# # Grundlagen

# %% [markdown]
# ## Daten
# <a id='Daten'></a>

# %% [markdown]
# <a id='Daten_eintragen'></a>
# ### Daten eintragen

# %%
x = [0,1,2,3,4]
y = [2,4,1,5,3]
y2 = [4,2,5,1,0]

# %% [markdown]
# <a id='Daten_von_Datei_einlesen'></a>
# ### Daten von Datei einlesen
#
# <div class="alert alert-block alert-danger">
# <b>ToDo</b> hier muss noch Inhalt rein ...
# </div>

# %% [markdown]
# <a id='Funktionen'></a>
# ### Funktionen
#
#
# <div class="alert alert-block alert-danger">
# <b>ToDo</b> hier muss noch Inhalt rein ...
# </div>

# %% [markdown]
# <a id='Import'></a>
# ## Import der Matplotlib Bibliothek

# %%
# Bilbiothek importieren
import matplotlib.pyplot as plt

# %% [markdown]
# <a id='Scatter'></a>
# ## Scatter/Linien Plot
#
# <div class="alert alert-block alert-info">
# <b>Tipp:</b> Das Komma nach dem letzten Befehl hat nur einen kosmetischen Grund, weil es die Ausgabe des letzten Befehls unterdrückt.
# </div>

# %%
plt.plot(x,y);

# %% [markdown]
# <a id='Linien'></a>
# ### Linien (Typ , Farbe , Dicke)
#
# <div class="alert alert-block alert-info">
# <b>Hinweis zur Linienfarbe:</b> Wenn die Linienfarbe selbstständig definiert wird, so wird für jeden neuen plot selbstständig eine neue Liniefarbe gewählt
# </div>
#
# **`ls` - Linienstil**
# <img src="figures/ls.png" width=300px>
#
# **`c` - Linienfarbe**
# <img src="figures/colors.png" width=300px>
#
# **`lw` - Liniendicke**
# default=1
#
# Bilder aus: [offizielle CheatSheets von Nicolas P. Rougier](https://github.com/matplotlib/cheatsheets/)

# %%
plt.plot(x,y,ls="-",c="blue",lw=1);
plt.plot(x,y2,ls="--",c="red",lw=3);

# %% [markdown]
# <a id='Marker'></a>
# ### Marker (Typ , Farbe , Dicke)
#
# **`marker` - Markerstil**
# <img src="figures/markers.png" width=300px>
#
# **`markevery` - Anzahl**
# <img src="figures/markevery.png" width=300px>
#
# **`ms` - Markergröße**
#
# Bilder aus: [offizielle CheatSheets von Nicolas P. Rougier](https://github.com/matplotlib/cheatsheets/)

# %%
plt.plot(x,y,marker="o",ms=10);
plt.plot(x,y2,marker="s",ms=15,markevery=[0,-1]);

# %% [markdown]
# <a id='Beschriftungen'></a>
# ## Beschriftungen

# %% [markdown]
# <a id='Achsenbeschriftung'></a>
# ### Achsenbeschriftung
#
#
# - `plt.xlabel(" ")`
# - `plt.ylabel(" ")`
#
# bzw.
#
# - `ax.set_xlabel(" ")`
# - `ax.set_ylabel(" ")`

# %%
plt.plot(x,y,marker="o",ms=10);
plt.plot(x,y2,marker="s",ms=15,markevery=[0,-1]);
plt.xlabel("Weg [mm]");
plt.ylabel("Kraft [N]");

# %% [markdown]
# <a id='Bildueberschrift'></a>
# ### Bildüberschrift
#
# - `plt.title(" ")`
#
# bzw.
#
# - `ax.set_title(" ")`

# %%
plt.plot(x,y,marker="o",ms=10);
plt.plot(x,y2,marker="s",ms=15,markevery=[0,-1]);
plt.title("Erster Plot");

# %% [markdown]
# <a id='Legende'></a>
# ### Legende
#
# - `label=' '` Bennenung im plot Befehl
# - `plt.legend()` Legende anzeigen
#
# <div class="alert alert-block alert-danger">
# <b>ToDo</b> Legenden Positionen
# </div>

# %%
plt.plot(x,y,marker="o",ms=10, label='Messung 1');
plt.plot(x,y2,marker="s",ms=15,markevery=[0,-1], label='Messung 2');
plt.title("Erster Plot");
plt.legend();

# %% [markdown]
# <a id='WertebereichAchsen'></a>
# ## Wertebereich der Achsen
#
# beide Werte vorgeben:
# - `plt.xlim(x1,x2)`
# - `plt.ylim(y1,y2)`
#
# nur einen Wert vorgeben:
# - `plt.xlim(left=x1)` oder `plt.xlim(right=x2)`
# - `plt.ylim(bottom=y1)` oder `plt.xlim(top=y2)`

# %%
plt.plot(x,y,marker="o",ms=10);
plt.plot(x,y2,marker="s",ms=15,markevery=[0,-1]);
plt.xlim(0,3);
plt.ylim(0,4);

# %% [markdown]
# <a id='Gitter'></a>
# ## Gitter
#
# - `plt.grid()`

# %%
plt.plot(x,y,marker="o",ms=10);
plt.plot(x,y2,marker="s",ms=15,markevery=[0,-1]);
plt.grid();

# %% [markdown]
# <a id='Bildgroesse'></a>
# ## Bildgröße
#
# <div class="alert alert-block alert-info">
# <b>Hinweis:</b> Befehl muss vor dem plotten kommen
# </div>
#
# `plt.figure(figsize=(8,5))` - Größe in inces (Default: 6,4)

# %%
plt.figure(figsize=(8,5));
plt.plot(x,y,marker="o",ms=10);
plt.plot(x,y2,marker="s",ms=15,markevery=[0,-1]);

# %% [markdown]
# <a id='Schriftgroesse'></a>
# ## Schriftgröße
#
# <div class="alert alert-block alert-info">
# <b>Hinweis:</b> globaler Paramter bleibt für alle weitern Plots aktiv können aber mit ( <b>mpl.rcParams.update(mpl.rcParamsDefault</b> ) zurückgesetzt werden.
# </div>
#
# global:
# - `plt.rcParams.update({'font.size': 20})`
#
# individuell:
# <div class="alert alert-block alert-danger">
# <b>ToDo</b>
# </div>

# %%
plt.rcParams.update({'font.size': 20});
plt.plot(x,y,marker="o",ms=10);
plt.plot(x,y2,marker="s",ms=15,markevery=[0,-1]);

# %% [markdown]
# <a id='Speichern'></a>
# ## Bild speichern
#
# `plt.savefig('Name.png', bbox_inches='tight', dpi=150)`

# %%
plt.plot(x,y,marker="o",ms=10);
plt.plot(x,y2,marker="s",ms=15,markevery=[0,-1]);
plt.savefig('Name.png', bbox_inches='tight', dpi=150)
