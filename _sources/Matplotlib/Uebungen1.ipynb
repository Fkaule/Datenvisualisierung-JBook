# %% [markdown]
# # Übungen 1
#
# Erstellen Sie mit Hilfe der Informationen aus dem [Kapitel Grundlagen](Grundlagen.ipynb) folgende Grafiken:
#
# <div class="alert alert-block alert-info">
#     Um <b>Hinweise</b> zu bekommen klicken Sie auf <b>click to show</b> in jeweiligen Abschnitt <b>Hinweise</b>
# </div>
#
# <div class="alert alert-block alert-info">
#     Um die <b>Lösung</b> zu bekommen klicken Sie auf <b>click to show</b> im jeweiligen Abschnitt <b>Plot</b>
# </div>

# %% [markdown]
# <a id='Uebung1'></a>
# ## Übung 1

# %% [markdown]
# ### Daten

# %%
x = [0,1,2,3,4]
y = [2,4,1,5,3]

# %% [markdown]
# ### Hinweise

# %%
# mit dem  Befehl `plt.plot()` plotten Sie

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt
plt.plot(x,y);
plt.savefig('Uebung01.png', bbox_inches='tight', dpi=100)
